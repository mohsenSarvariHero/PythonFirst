# %% [markdown]
# <a href="https://colab.research.google.com/github/mohsenSarvariHero/PythonFirst/blob/main/Q12-B-HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Re-importing necessary libraries after reset
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mu = 40  # mean speed for law-abiding drivers
sigma = 2.89  # standard deviation of the sample mean
threshold = 45.06  # calculated threshold
alpha = 0.04  # significance level

# Create the x-axis for the normal distribution
x = np.linspace(mu - 4 * sigma, mu + 4 * sigma, 1000)
y = norm.pdf(x, mu, sigma)

# Plot the normal distribution
plt.figure(figsize=(10, 6))
plt.plot(x, y, label="Distribution of sample mean ($\\bar{x}$)", color="blue")

# Fill the rejection area
x_fill = np.linspace(threshold, mu + 4 * sigma, 500)
y_fill = norm.pdf(x_fill, mu, sigma)
plt.fill_between(x_fill, y_fill, color="red", alpha=0.6, label="Rejection area (α = 0.04)")

# Add vertical lines for mean and threshold
plt.axvline(mu, color="green", linestyle="--", label="Mean ($\\mu = 40$ mph)")
plt.axvline(threshold, color="red", linestyle="--", label=f"Threshold ($\\bar{{x}} = {threshold:.2f}$ mph)")

# Labels and legend
plt.title("Distribution of Sample Mean ($\\bar{x}$) and Rejection Area", fontsize=14)
plt.xlabel("Sample Mean ($\\bar{x}$)", fontsize=12)
plt.ylabel("Probability Density", fontsize=12)
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

plt.show()
